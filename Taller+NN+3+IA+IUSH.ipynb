# %%
import numpy as np
import pandas as pd
import urllib

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/poker/poker-hand-training-true.data"
col_names =['S1', 'C1', 'S2', 'C2', 'S3', 'C3', 'S4', 'C4', 'S5', 'C5','CLASS']
poker = pd.read_csv(url,header=None, names=col_names)

# %%
poker.head()
# Out:
#    S1  C1  S2  C2  S3  C3  S4  C4  S5  C5  CLASS
# 0   1  10   1  11   1  13   1  12   1   1      9
# 1   2  11   2  13   2  10   2  12   2   1      9
# 2   3  12   3  11   3  13   3  10   3   1      9
# 3   4  10   4  11   4   1   4  13   4  12      9
# 4   4   1   4  13   4  12   4  11   4  10      9

# %%
poker.describe()
# Out:
#                  S1            C1            S2            C2            S3  \
# count  25010.000000  25010.000000  25010.000000  25010.000000  25010.000000
# mean       2.508756      6.995242      2.497721      7.014194      2.510236
# std        1.116483      3.749805      1.121767      3.766974      1.123148
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      4.000000      1.000000      4.000000      2.000000
# 50%        3.000000      7.000000      2.000000      7.000000      3.000000
# 75%        4.000000     10.000000      4.000000     10.000000      4.000000
# max        4.000000     13.000000      4.000000     13.000000      4.000000
#
#                  C3            S4            C4            S5            C5  \
# count  25010.000000  25010.000000  25010.000000  25010.000000  25010.000000
# mean       7.014154      2.495922      6.942463      2.497321      6.962735
# ...

# %%
poker
# Out:
#        S1  C1  S2  C2  S3  C3  S4  C4  S5  C5  CLASS
# 0       1  10   1  11   1  13   1  12   1   1      9
# 1       2  11   2  13   2  10   2  12   2   1      9
# 2       3  12   3  11   3  13   3  10   3   1      9
# 3       4  10   4  11   4   1   4  13   4  12      9
# 4       4   1   4  13   4  12   4  11   4  10      9
# 5       1   2   1   4   1   5   1   3   1   6      8
# 6       1   9   1  12   1  10   1  11   1  13      8
# 7       2   1   2   2   2   3   2   4   2   5      8
# 8       3   5   3   6   3   9   3   7   3   8      8
# 9       4   1   4   4   4   2   4   3   4   5      8
# 10      1   1   2   1   3   9   1   5   2   3      1
# 11      2   6   2   1   4  13   2   4   4   9      0
# 12      1  10   4   6   1   2   1   1   3   8      0
# 13      2  13   2   1   4   4   1   5   2  11      0
# 14      3   8   4  12   3   9   4   2   3   2      1
# 15      1   3   4   7   1   5   2   4   4  13      0
# 16      1   4   1   1   1   3   3   5   3   2      4
# ...

# %%
poker.describe().transpose()
# Out:
#          count      mean       std  min  25%  50%   75%   max
# S1     25010.0  2.508756  1.116483  1.0  2.0  3.0   4.0   4.0
# C1     25010.0  6.995242  3.749805  1.0  4.0  7.0  10.0  13.0
# S2     25010.0  2.497721  1.121767  1.0  1.0  2.0   4.0   4.0
# C2     25010.0  7.014194  3.766974  1.0  4.0  7.0  10.0  13.0
# S3     25010.0  2.510236  1.123148  1.0  2.0  3.0   4.0   4.0
# C3     25010.0  7.014154  3.744974  1.0  4.0  7.0  10.0  13.0
# S4     25010.0  2.495922  1.116009  1.0  1.0  2.0   3.0   4.0
# C4     25010.0  6.942463  3.747147  1.0  4.0  7.0  10.0  13.0
# S5     25010.0  2.497321  1.118732  1.0  1.0  3.0   3.0   4.0
# C5     25010.0  6.962735  3.741579  1.0  4.0  7.0  10.0  13.0
# CLASS  25010.0  0.621152  0.788361  0.0  0.0  1.0   1.0   9.0

# %%
y=poker.values[:,10]

# %%
y
# Out:
# array([9, 9, 9, ..., 1, 1, 1], dtype=int64)

# %%
X=poker.values[:,0:11]

# %%
X
# Out:
# array([[ 1, 10,  1, ...,  1,  1,  9],
#        [ 2, 11,  2, ...,  2,  1,  9],
#        [ 3, 12,  3, ...,  3,  1,  9],
#        ...,
#        [ 2,  1,  2, ...,  4, 13,  1],
#        [ 2, 12,  4, ...,  4,  9,  1],
#        [ 1,  7,  3, ...,  3,  7,  1]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# C:\Users\sala307\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# C:\Users\sala307\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier(hidden_layer_sizes=(13,13,13),max_iter=500,alpha=0.02)

# %%
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.02, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(13, 13, 13), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=500, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
clf = MLPClassifier(hidden_layer_sizes=(100,100,100), max_iter=500, alpha=0.0001,
                     solver='sgd', verbose=10,  random_state=21,tol=0.000000001)

# %%
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# Iteration 1, loss = 1.48289102
# Iteration 2, loss = 0.94347323
# Iteration 3, loss = 0.75989628
# Iteration 4, loss = 0.56577748
# Iteration 5, loss = 0.40599565
# Iteration 6, loss = 0.30801502
# Iteration 7, loss = 0.24874444
# Iteration 8, loss = 0.20894345
# Iteration 9, loss = 0.18074674
# Iteration 10, loss = 0.16022821
# Iteration 11, loss = 0.14445420
# Iteration 12, loss = 0.13198202
# Iteration 13, loss = 0.12185227
# Iteration 14, loss = 0.11338427
# Iteration 15, loss = 0.10620947
# Iteration 16, loss = 0.10004663
# Iteration 17, loss = 0.09469610
# Iteration 18, loss = 0.09008166
# Iteration 19, loss = 0.08600924
# Iteration 20, loss = 0.08242040
# Iteration 21, loss = 0.07917677
# Iteration 22, loss = 0.07622441
# Iteration 23, loss = 0.07354764
# Iteration 24, loss = 0.07108303
# Iteration 25, loss = 0.06877076
# Iteration 26, loss = 0.06664814
# Iteration 27, loss = 0.06459613
# Iteration 28, loss = 0.06267444
# Iteration 29, loss = 0.06086101
# ...

# %%
predictions = mlp.predict(X_test)

# %%
predictions[1]
# Out:
# 1

# %%
y_test[1]
# Out:
# 1

# %%
from sklearn.metrics import classification_report

# %%
# %%timeit
print(classification_report(y_test,predictions))
# Out:
# C:\Users\sala307\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      3130
#           1       1.00      1.00      1.00      2645
#           2       1.00      1.00      1.00       304
#           3       1.00      1.00      1.00       135
#           4       1.00      1.00      1.00        20
#           5       1.00      1.00      1.00        12
#           6       0.60      1.00      0.75         3
#           7       0.00      0.00      0.00         2
#           8       0.00      0.00      0.00         1
#           9       0.50      1.00      0.67         1
#
# avg / total       1.00      1.00      1.00      6253
#
# ...

# %%
mlp.score(X_test,y_test)
# Out:
# 0.99952023028946102

# %%
clf = MLPClassifier(hidden_layer_sizes=(100,100,100), max_iter=280, alpha=0.02,
                     solver='sgd', verbose=10,  random_state=21,tol=0.000000001)

# %%
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# Iteration 1, loss = 1.49483592
# Iteration 2, loss = 0.95552391
# Iteration 3, loss = 0.77210756
# Iteration 4, loss = 0.57816826
# Iteration 5, loss = 0.41847612
# Iteration 6, loss = 0.32053121
# Iteration 7, loss = 0.26130206
# Iteration 8, loss = 0.22153803
# Iteration 9, loss = 0.19337303
# Iteration 10, loss = 0.17288439
# Iteration 11, loss = 0.15714168
# Iteration 12, loss = 0.14470071
# Iteration 13, loss = 0.13460249
# Iteration 14, loss = 0.12616397
# Iteration 15, loss = 0.11901629
# Iteration 16, loss = 0.11288115
# Iteration 17, loss = 0.10755436
# Iteration 18, loss = 0.10296051
# Iteration 19, loss = 0.09890760
# Iteration 20, loss = 0.09533688
# Iteration 21, loss = 0.09211013
# Iteration 22, loss = 0.08917475
# Iteration 23, loss = 0.08651409
# Iteration 24, loss = 0.08406482
# Iteration 25, loss = 0.08176823
# Iteration 26, loss = 0.07966045
# Iteration 27, loss = 0.07762305
# Iteration 28, loss = 0.07571554
# Iteration 29, loss = 0.07391640
# ...

# %%
mlp.score(X_test,y_test)
# Out:
# 0.99952023028946102

# %%
# %%timeit
print(classification_report(y_test,predictions))
# Out:
# C:\Users\sala307\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      3130
#           1       1.00      1.00      1.00      2645
#           2       1.00      1.00      1.00       304
#           3       1.00      1.00      1.00       135
#           4       1.00      1.00      1.00        20
#           5       1.00      1.00      1.00        12
#           6       0.60      1.00      0.75         3
#           7       0.00      0.00      0.00         2
#           8       0.00      0.00      0.00         1
#           9       0.50      1.00      0.67         1
#
# avg / total       1.00      1.00      1.00      6253
#
# ...
